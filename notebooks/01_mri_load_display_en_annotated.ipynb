# %% [markdown]
# ## Import Required Libraries
#
# We use standard Python libraries to load and visualize MRI images:
# - `PIL` for image handling
# - `matplotlib` for plotting
# - `os` for file operations

# %%
# !pip install kaggle
from google.colab import files
files.upload()  # upload kaggle.json
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
# !unzip brain-tumor-mri-dataset.zip
# Out:
# ...
#      <input type="file" id="files-916695a2-eec5-4572-abdf-9295a72e60b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-916695a2-eec5-4572-abdf-9295a72e60b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Import Required Libraries
#
# We use standard Python libraries to load and visualize MRI images:
# - `PIL` for image handling
# - `matplotlib` for plotting
# - `os` for file operations

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

# Example path: you can adjust index as needed
img_path = "Training/glioma/" + os.listdir("Training/glioma")[400]
img = Image.open(img_path)

plt.imshow(img, cmap='gray')  # If image is grayscale, use 'gray' colormap
plt.title("Example Glioma MRI")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Import Required Libraries
#
# We use standard Python libraries to load and visualize MRI images:
# - `PIL` for image handling
# - `matplotlib` for plotting
# - `os` for file operations

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image

base_dir = "Training"
categories = ["glioma", "meningioma", "pituitary", "notumor"]

plt.figure(figsize=(10, 8))
for i, cat in enumerate(categories):
    img_path = os.path.join(base_dir, cat, os.listdir(os.path.join(base_dir, cat))[5])
    img = Image.open(img_path)
    plt.subplot(2, 2, i+1)
    plt.imshow(img, cmap='gray')
    plt.title(cat.capitalize())
    plt.axis('off')
plt.tight_layout()
plt.show()
